# %% [markdown]
# <a href="https://colab.research.google.com/github/Omkar210/Python-Practice/blob/main/Python_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Is number happy prime number

# %%
def prime(n):
    for i in range(2,n):
        if n % i == 0:
            return  False
        else:
            if n % i == 0:
                break
    return True
# prime(4)

# %%
def happy(n):
    while n != 1 and n != 4:
        n = sum(int(digit) ** 2 for digit in str(n))
    return n == 1

# happy(7)

# %%
def is_happy_prime(n):
    if prime(n) and happy(n):
        print('It is happy prime number')
    else:
        print('It is not happy prime number')

is_happy_prime(7)
# Out:
# It is happy prime number

# %% [markdown]
# # Strong Number

# %%
def strong(n):
    sum = 0
    temp = n
    while n > 0:
        rem = n % 10

        fact = 1
        for i in range(1,rem+1):
            fact *= i

        sum += fact
        n //= 10
    return sum == temp

# %%
if strong(14):
    print('strong number')
else:
    print('not strong number')
# Out:
# It is not strong number

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("muhammadmusharraf444/loan-approval-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /root/.cache/kagglehub/datasets/muhammadmusharraf444/loan-approval-dataset/versions/1

# %%
import pandas as pd

df = pd.read_csv('/root/.cache/kagglehub/datasets/muhammadmusharraf444/loan-approval-dataset/versions/1/loan_data_new.csv')
df.head()
# Out:
#    Age  Gender    Education  Person Income  Employee Experience  \
# 0   22  female       Master          71948                    0
# 1   21  female  High School          12282                    0
# 2   25  female  High School          12438                    3
# 3   23  female     Bachelor          79753                    0
# 4   24    male       Master          66135                    1
#
#   Home Onwership  Loan Amount Loan Intent  Loan interest Rate  \
# 0           RENT        35000    PERSONAL               16.02
# 1            OWN         1000   EDUCATION               11.14
# 2       MORTGAGE         5500     MEDICAL               12.87
# 3           RENT        35000     MEDICAL               15.23
# 4           RENT        35000     MEDICAL               14.27
#
#    Loan percentage  Credit History  Credit Score Previous Loan  Loan Status
# 0             0.49               3           561            No            1
# ...

# %%
df.shape
# Out:
# (45000, 14)

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Education', 'Person Income', 'Employee Experience',
#        'Home Onwership', 'Loan Amount', 'Loan Intent', 'Loan interest Rate',
#        'Loan percentage', 'Credit History', 'Credit Score', 'Previous Loan',
#        'Loan Status'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Age                      int64
# Gender                  object
# Education               object
# Person Income            int64
# Employee Experience      int64
# Home Onwership          object
# Loan Amount              int64
# Loan Intent             object
# Loan interest Rate     float64
# Loan percentage        float64
# Credit History           int64
# Credit Score             int64
# Previous Loan           object
# Loan Status              int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Age                    0
# Gender                 0
# Education              0
# Person Income          0
# Employee Experience    0
# Home Onwership         0
# Loan Amount            0
# Loan Intent            0
# Loan interest Rate     0
# Loan percentage        0
# Credit History         0
# Credit Score           0
# Previous Loan          0
# Loan Status            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import numpy as np

df.iloc[np.where(df['Loan Status']==1)[0]]

len(np.where(df['Loan Status']==0)[0])
# Out:
# 35000

# %%
(len(np.where(df['Loan Status']==0)[0])/df.shape[0])*100
# Out:
# 77.77777777777779

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x=df['Loan Status'],data=df)
plt.title('Counting Loan Status')
plt.xlabel('Loan Status')
plt.ylabel('Count')
plt.show()

# %%
df['Loan Status'].value_counts()
# Out:
# Loan Status
# 0    35000
# 1    10000
# Name: count, dtype: int64

# %%
min(df['Age'])
# Out:
# 20

# %%
max(df['Age'])
# Out:
# 144

# %%
np.average(df.Age)
# Out:
# np.float64(27.76417777777778)

# %%
sns.histplot(x=df['Age'],data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
bin = [20,30,40,50,60,70,80,np.inf]
df['age_group'] = pd.cut(df['Age'],bins=bin)
df['age_group'].value_counts()
# Out:
# age_group
# (20.0, 30.0]    34382
# (30.0, 40.0]     8762
# (40.0, 50.0]     1511
# (50.0, 60.0]      250
# (60.0, 70.0]       63
# (80.0, inf]         9
# (70.0, 80.0]        6
# Name: count, dtype: int64

# %%
sns.countplot(x=df['age_group'],data=df,hue=df['age_group'])
plt.xticks(rotation=45)
plt.title('Counting Age Group')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.show()
